# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import cv2
from skimage.measure import compare_ssim as ssim

data_path = '/Users/frodo/Documents/placement/data/'
moon_data_path = data_path + 'moon/'
normal_data_path = data_path + 'fireworks/normal/'
abnormal_data_path = data_path + 'fireworks/abnormal/'
image_mean_path = data_path + 'night/mean.png'
image_mean_col = cv2.imread(image_mean_path)
image_mean = cv2.cvtColor(image_mean_col, cv2.COLOR_BGR2GRAY)
score_normal = []
score_abnormal = []

for img in os.listdir(abnormal_data_path):
    image_col = cv2.imread(abnormal_data_path + img)
    image = cv2.cvtColor(image_col, cv2.COLOR_BGR2GRAY)
    score = ssim(image_mean, image)
    score_abnormal.append(score)
    
for img in os.listdir(normal_data_path):
    image_col = cv2.imread(normal_data_path + img)
    image = cv2.cvtColor(image_col, cv2.COLOR_BGR2GRAY)
    score = ssim(image_mean, image)
    score_normal.append(score)

plt.hist(score_normal, label='no fireworks')
plt.hist(score_abnormal, label='fireworks', alpha = 0.5)
plt.legend(loc='best')
plt.xlabel('Structural Similarity Index')
plt.ylabel('Counts')
# Out:
# Text(0,0.5,'Counts')

# %%
ssim_dict = dict()
# ssim_dict.setdefault('a', []).append('apple')
for img in os.listdir(abnormal_data_path):
    image_col = cv2.imread(abnormal_data_path + img)
    image = cv2.cvtColor(image_col, cv2.COLOR_BGR2GRAY)
    score = ssim(image_mean, image)
    score_abnormal.append(score)
    ssim_dict[score]= [img]

# print ssim_dict
# Out:
# {0.30217966532756296: ['N2_0138.png'], 0.3806691200715927: ['N2_0134.png'], 0.5199416356074602: ['N2_0137.png'], 0.33477587074213216: ['N2_0123.png'], 0.5952736661260983: ['N2_0132.png'], 0.44271079583735745: ['N2_0133.png'], 0.27120245656105085: ['N2_0128.png'], 0.5654161849472266: ['N2_0119.png'], 0.28654565057165576: ['N2_0127.png'], 0.5443742014210423: ['N2_0125.png'], 0.17798196633747937: ['N2_0116.png'], 0.2931023414818453: ['N2_0118.png'], 0.6947784486853307: ['N2_0126.png'], 0.631947198831343: ['N2_0124.png'], 0.5571446823669454: ['N2_0117.png'], 0.3638261171944241: ['N2_0130.png'], 0.34204249844585677: ['N2_0136.png'], 0.5752853028040957: ['N2_0122.png'], 0.4184543142136234: ['N2_0135.png'], 0.5642957017676635: ['N2_0121.png'], 0.5173724235835042: ['N2_0120.png'], 0.425252614552565: ['N2_0131.png'], 0.6891181456405799: ['N2_0129.png']}

# %%
ssim_dict[min(ssim_dict.keys())]
# Out:
# ['N2_0116.png']

# %%
max(ssim_dict)
# Out:
# 0.6947784486853307

# %%
ssim_dict[max(ssim_dict.keys())]
# Out:
# ['N2_0126.png']

# %%
ssim_normal_dict = dict()
for img in os.listdir(normal_data_path):
    image_col = cv2.imread(normal_data_path + img)
    image = cv2.cvtColor(image_col, cv2.COLOR_BGR2GRAY)
    score = ssim(image_mean, image)
    score_normal.append(score)
    ssim_normal_dict[score] = [img]
print ssim_normal_dict
# Out:
340235148355: ['N2_0220.png'], 0.8372261069375164: ['N2_0066.png'], 0.8653738821407818: ['N2_0186.png'], 0.8512786553625742: ['N2_0071.png'], 0.7927279055163402: ['N3_0062.png'], 0.8723759248696682: ['N2_0005.png'], 0.8306898692123855: ['N2_0013.png'], 0.9211856961499167: ['N2_0155.png'], 0.7802016381653696: ['N1_0048.png'], 0.8789050125131883: ['N2_0175.png'], 0.8023831509026345: ['N2_0243.png'], 0.9058465624024122: ['N2_0171.png'], 0.819143989154486: ['N3_0051.png'], 0.9121081628712779: ['N2_0085.png'], 0.8846916956315115: ['N2_0196.png'], 0.9036502651767649: ['N3_0040.png'], 0.8016388277361259: ['N1_0014.png'], 0.7693214288139388: ['N3_0074.png'], 0.6736416714608348: ['N1_0026.png'], 0.8211741400794107: ['N1_0038.png'], 0.8471929992473854: ['N2_0230.png'], 0.8892030691337355: ['N2_0081.png'], 0.8863546833465321: ['N2_0184.png'], 0.8765921583703616: ['N2_0022.png'], 0.7526981833107143: ['N1_0028.png'], 0.8894207498662126: ['N2_0007.png'], 0.8788359201831479: ['N2_0251.png'], 0.9005670604519419: ['N2_0099.png'], 0.8773377010327668: ['N2_0076.png'], 0.8780196123960385: ['N2_0075.png'], 0.81580782 ...

# %%
score_moon = []
score = 0
ssim_moon_dict = dict()
moon_data_path = data_path + 'moon/'
for img in os.listdir(moon_data_path):
    image_col = cv2.imread(moon_data_path + img)
    image = cv2.cvtColor(image_col, cv2.COLOR_BGR2GRAY)
    score = ssim(image_mean, image)
    score_moon.append(score)
    ssim_moon_dict[score] = [img]
print 
print "min(ssim_moon_dict): " + str(min(ssim_moon_dict))
print "ssim_dict[min(ssim_moon_dict.keys())]: " + str(ssim_moon_dict[min(ssim_moon_dict.keys())])
print 
print "max(ssim_moon_dict): " + str(max(ssim_moon_dict))
print "ssim_dict[max(ssim_moon_dict.keys())]: " + str(ssim_moon_dict[max(ssim_moon_dict.keys())])

plt.hist(score_moon, label='moon')
plt.hist(score_abnormal, label='fireworks', alpha = 0.5)
plt.hist(score_normal, label='no fireworks', alpha = 0.5)
plt.legend(loc='best')
plt.xlabel('Structural Similarity Index')
plt.ylabel('Counts')
# Out:
# min(ssim_moon_dict): 0.8023831509026345
# ssim_dict[min(ssim_moon_dict.keys())]: ['N2_0243.png']
#
# max(ssim_moon_dict): 0.9305419525326162
# ssim_dict[max(ssim_moon_dict.keys())]: ['N2_0237.png']
# Text(0,0.5,'Counts')

# %%
plt.hist(score_normal, label='no fireworks', alpha = 0.5)
plt.hist(score_abnormal, label='fireworks', alpha = 0.5)
plt.hist(score_moon, label='moon')
plt.legend(loc='best')
plt.xlabel('Structural Similarity Index')
plt.ylabel('Counts')
# Out:
# Text(0,0.5,'Counts')

# %% [markdown]
# import json
# fp = open('/Users/frodo/Desktop/normal_dict.json','wb+')
# print ssim_normal_dict
# json.dump(ssim_normal_dict, fp, sort_keys=True, indent=4)

# %%
import cv2
import numpy as np

img = cv2.imread('/Users/frodo/Desktop/test.png',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,20,
                         param1=50,param2=30,minRadius=0,maxRadius=0)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

cv2.imshow('detected circles',cimg)
cv2.waitKey(0) 
cv2.destroyAllWindows()
